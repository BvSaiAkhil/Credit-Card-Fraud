# %%
import os 
os.chdir('/home/akhilbvs/Kaggle/creditcardfraud')

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
data_set=pd.read_csv('creditcard.csv')

# %%
data_set.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...         V21       V22       V23       V24  \
# 0  0.098698  0.363787  ...   -0.018307  0.277838 -0.110474  0.066928
# 1  0.085102 -0.255425  ...   -0.225775 -0.638672  0.101288 -0.339846
# 2  0.247676 -1.514654  ...    0.247998  0.771679  0.909412 -0.689281
# 3  0.377436 -1.387024  ...   -0.108300  0.005274 -0.190321 -1.175575
# 4 -0.270533  0.817739  ...   -0.009431  0.798278 -0.137458  0.141267
#
#         V25       V26       V27       V28  Amount  Class
# ...

# %%
data_set.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.165980e-15  3.416908e-16 -1.373150e-15  2.086869e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.490107e-15 -5.556467e-16  1.177556e-16 -2.406455e-15
# ...

# %%
class_names = {0:'Not Fraud', 1:'Fraud'}
print(data_set['Class'].value_counts().rename(index=class_names))
# Out:
# Not Fraud    284315
# Fraud           492
# Name: Class, dtype: int64

# %%
plt.figure(figsize=(25,20))
plt.subplot(5, 6, 1);plt.plot(data_set['V1']);plt.subplot(5, 6, 15);plt.plot(data_set['V15'])
plt.subplot(5, 6, 2);plt.plot(data_set['V2']);plt.subplot(5, 6, 16);plt.plot(data_set['V16'])
plt.subplot(5, 6, 3);plt.plot(data_set['V3']);plt.subplot(5, 6, 17);plt.plot(data_set['V17'])
plt.subplot(5, 6, 4);plt.plot(data_set['V4']);plt.subplot(5, 6, 18);plt.plot(data_set['V18'])
plt.subplot(5, 6, 5);plt.plot(data_set['V5']);plt.subplot(5, 6, 19);plt.plot(data_set['V19'])
plt.subplot(5, 6, 6);plt.plot(data_set['V6']);plt.subplot(5, 6, 20);plt.plot(data_set['V20'])
plt.subplot(5, 6, 7);plt.plot(data_set['V7']);plt.subplot(5, 6, 21);plt.plot(data_set['V21'])
plt.subplot(5, 6, 8);plt.plot(data_set['V8']);plt.subplot(5, 6, 22);plt.plot(data_set['V22'])
plt.subplot(5, 6, 9);plt.plot(data_set['V9']);plt.subplot(5, 6, 23);plt.plot(data_set['V23'])
plt.subplot(5, 6, 10);plt.plot(data_set['V10']);plt.subplot(5, 6, 24) ; plt.plot(data_set['V24'])
plt.subplot(5, 6, 11);plt.plot(data_set['V11']);plt.subplot(5, 6, 25) ; plt.plot(data_set['V25'])
plt.subplot(5, 6, 12);plt.plot(data_set['V12']);plt.subplot(5, 6, 26) ; plt.plot(data_set['V26'])
plt.subplot(5, 6, 13);plt.plot(data_set['V13']);plt.subplot(5, 6, 27) ; plt.plot(data_set['V27'])
plt.subplot(5, 6, 14);plt.plot(data_set['V14']);plt.subplot(5, 6, 28) ; plt.plot(data_set['V28'])
plt.subplot(5, 6, 29);plt.plot(data_set['Amount'])
plt.show()

# %%
x=data_set.iloc[:,1:30].values
y=data_set.iloc[:,30].values

# %%
from sklearn.cross_validation import train_test_split
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=0)

# %%
#Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
LRmodel=LogisticRegression(random_state=0)

# %%
LRmodel.fit(x_train,y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=0, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
y_predLR=LRmodel.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix

# %%
cm_LR=confusion_matrix(y_test,y_predLR)

# %%
plt.figure(figsize=(15,7))
data_frameLR=pd.DataFrame(cm_LR,index=['Not Fraud','Fraud'],columns=['Not Fraud','Fraud'])
sns.heatmap(data_frameLR,cmap='Blues',annot=True,fmt='g')
plt.show()

# %%
from sklearn.metrics import f1_score,recall_score

# %%
f1_scoreLR=f1_score(y_test,y_predLR)
recall_scoreLR=recall_score(y_test,y_predLR)
print('F1 score for Logistic Regression Model:{}'.format(f1_scoreLR))
print('Recall score for Logistic Regression Model:{}'.format(recall_scoreLR))
# Out:
# F1 score for Logistic Regression Model:0.728
# Recall score for Logistic Regression Model:0.6190476190476191

# %%
#KNN Model

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier()
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#            weights='uniform')

# %%
y_predknn=knn.predict(x_test)

# %%
cm_knn=confusion_matrix(y_test,y_predknn)

# %%
plt.figure(figsize=(15,7))
data_frameknn=pd.DataFrame(cm_knn,index=['Not Fraud','Fraud'],columns=['Not Fraud','Fraud'])
sns.heatmap(data_frameknn,cmap='Blues',annot=True,fmt='g')
plt.show()

# %%
f1_scoreknn=f1_score(y_test,y_predknn)
recall_scoreknn=recall_score(y_test,y_predLR)
print('F1 score for K Nearest Neighbours Model:{}'.format(f1_scoreknn))
print('Recall score for K Nearest Neighbours Model:{}'.format(recall_scoreknn))
# Out:
# F1 score for K Nearest Neighbours Model:0.7729083665338646
# Recall score for K Nearest Neighbours Model:0.6190476190476191
